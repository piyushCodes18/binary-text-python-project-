# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushCodes18/binary-text-python-project-/blob/main/netflix_complete_AIproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('netflix_titles-AI-final.csv')

x = dataset.iloc[:,:-1]
y = dataset.iloc[:,1]

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
dataset
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802     NaN      NaN                    NaN              NaN
# 8803     NaN      NaN                    NaN              NaN
# 8804     NaN      NaN                    NaN              NaN
# 8805     NaN      NaN                    NaN              NaN
# 8806     NaN      NaN                    NaN              NaN
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
x
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802     NaN      NaN                    NaN              NaN
# 8803     NaN      NaN                    NaN              NaN
# 8804     NaN      NaN                    NaN              NaN
# 8805     NaN      NaN                    NaN              NaN
# 8806     NaN      NaN                    NaN              NaN
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
y
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802        NaN
# 8803        NaN
# 8804        NaN
# 8805        NaN
# 8806        NaN
# Name: type, Length: 8807, dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4999 non-null   object
#  1   type          4999 non-null   object
#  2   title         4999 non-null   object
#  3   director      3256 non-null   object
#  4   cast          4534 non-null   object
#  5   country       4371 non-null   object
#  6   date_added    4999 non-null   object
#  7   release_year  4999 non-null   float64
#  8   rating        4999 non-null   object
#  9   duration      4999 non-null   object
#  10  listed_in     4999 non-null   object
#  11  description   4999 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 825.8+ KB

# %%
dataset.isnull().sum()
# Out:
# show_id         3808
# type            3808
# title           3808
# director        5551
# cast            4273
# country         4436
# date_added      3808
# release_year    3808
# rating          3808
# duration        3808
# listed_in       3808
# description     3808
# dtype: int64

# %%
type_mean = dataset.groupby('type', as_index=False)['release_year'].mean()

type_mean
# Out:
#       type  release_year
# 0    Movie   2015.177570
# 1  TV Show   2018.096702

# %%
release_mean = dataset.groupby('release_year', as_index=False)['release_year'].mean()

release_mean.head()
# Out:
#    release_year
# 0        1925.0
# 1        1945.0
# 2        1954.0
# 3        1956.0
# 4        1958.0

# %%
rating_count = dataset.groupby('rating', as_index=False)['release_year'].mean()

rating_count
# Out:
#   rating  release_year
# 0      G   2005.583333
# 1     PG   2010.396694
# 2  PG-13   2011.370370
# 3      R   2012.784091
# 4  TV-14   2015.484227
# 5   TV-G   2017.868613
# 6  TV-MA   2017.696585
# 7  TV-PG   2016.543981
# 8   TV-Y   2018.123288
# 9  TV-Y7   2017.385417

# %%
country_count = dataset.groupby('country', as_index=False)['release_year'].mean()

country_count.head()
# Out:
#                                              country  release_year
# 0                                  , France, Algeria   2014.000000
# 1                                      , South Korea   2021.000000
# 2                                          Argentina   2017.694444
# 3  Argentina, Brazil, France, Poland, Germany, De...   2017.000000
# 4                                   Argentina, Chile   2006.000000

# %%
dataset.describe(include='all')
# Out:
#        show_id   type                        title       director  \
# count     4999   4999                         4999           3256
# unique    4999      2                         4999           2556
# top      s4999  Movie  Gad Elmaleh: American Dream  Rajiv Chilaka
# freq         1   3210                            1             17
# mean       NaN    NaN                          NaN            NaN
# std        NaN    NaN                          NaN            NaN
# min        NaN    NaN                          NaN            NaN
# 25%        NaN    NaN                          NaN            NaN
# 50%        NaN    NaN                          NaN            NaN
# 75%        NaN    NaN                          NaN            NaN
# max        NaN    NaN                          NaN            NaN
#
#                                                      cast        country  \
# count                                                4534           4371
# ...

# %%
corr = dataset.select_dtypes(include=['number']).corr()

corr
# Out:
#               release_year
# release_year           1.0

# %%
dataset.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
plt.bar(dataset['release_year'], dataset['show_id'].astype(str).str.extract('(\d+)')[0].fillna(0).astype(int), width=0.8)

plt.xlabel('Release Year')
plt.ylabel('Show ID')
plt.title('Release Year vs Show ID')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_7156/2326666194.py:1: SyntaxWarning: invalid escape sequence '\d'
#   plt.bar(dataset['release_year'], dataset['show_id'].astype(str).str.extract('(\d+)')[0].fillna(0).astype(int), width=0.8)

# %%
plt.scatter(
    dataset['release_year'],
    dataset['show_id'].astype(str).str.extract('(\d+)')[0].fillna(0).astype(int),
    s=40
)

plt.xlabel('Release Year')
plt.ylabel('Show ID')
plt.title('Scatter Plot')
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_7156/3301308156.py:3: SyntaxWarning: invalid escape sequence '\d'
#   dataset['show_id'].astype(str).str.extract('(\d+)')[0].fillna(0).astype(int),

# %%
avg_release = dataset['release_year'].mean()

print("Average Release Year:", avg_release)
# Out:
# Average Release Year: 2016.2222444488898

# %%
plt.hist(dataset['release_year'], bins=15)

plt.xlabel('Release Year')
plt.ylabel('Frequency')
plt.title('Histogram of Release Year')

plt.show()

# %%
counts = dataset['type'].value_counts()

plt.title('Type Distribution')
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')

plt.show()

# %%
counts = dataset['rating'].value_counts().head(10)

plt.title('Rating Distribution')
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')

plt.show()

# %%
plt.boxplot(dataset['release_year'])

plt.ylabel('Release Year')
plt.title('Box Plot of Release Year')

plt.show()

# %%
release_counts = dataset['release_year'].value_counts().sort_index()

plt.fill_between(release_counts.index, release_counts.values, alpha=0.5)

plt.xlabel("Release Year")
plt.ylabel("Content Count")
plt.title("Release Trend")

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')

plt.title("Correlation Heatmap")
plt.show()

# %%
x = dataset.drop('release_year', axis=1)

y = dataset['release_year']

# %%
x = x.fillna('Unknown')

y = y.fillna(y.mean())

x = pd.get_dummies(x, drop_first=True)

x.head()
# Out:
#    show_id_s1  show_id_s10  show_id_s100  show_id_s1000  show_id_s1001  \
# 0        True        False         False          False          False
# 1       False        False         False          False          False
# 2       False        False         False          False          False
# 3       False        False         False          False          False
# 4       False        False         False          False          False
#
#    show_id_s1002  show_id_s1003  show_id_s1004  show_id_s1005  show_id_s1006  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=0
)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of y_train: {y_train.shape}")

regressor.fit(x_train, y_train)

print("Model Trained Successfully")
# Out:
# Shape of x_train: (7045, 24074)
# Shape of y_train: (7045,)
# Model Trained Successfully

# %%
y_pred = regressor.predict(x_test)

y_pred
# Out:
# array([2020.16980283, 2016.11169516, 2022.22783308, ..., 2016.22224445,
#        2016.52620056, 2016.22224445])

# %%
y_test
# Out:
# 273     2021.000000
# 2038    2020.000000
# 462     2019.000000
# 8687    2016.222244
# 4105    2019.000000
#            ...
# 6707    2016.222244
# 6754    2016.222244
# 7219    2016.222244
# 4344    2018.000000
# 5722    2016.222244
# Name: release_year, Length: 1762, dtype: float64

# %%
from sklearn.metrics import r2_score

print(r2_score(y_test, y_pred))
# Out:
# 0.33878922443157355

# %%
x_train.size
# Out:
# 169601330

# %%
y_train.size
# Out:
# 7045

# %%
x_test.size
# Out:
# 42418388

# %%
y_test.size
# Out:
# 1762

# %%
plt.figure(figsize=(10, 6))

plt.scatter(y_test, y_pred, alpha=0.5)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle='--'
)

plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')

plt.show()

# %%
# Multiple Linear Regression

mlr = LinearRegression()

mlr.fit(x_train, y_train)

y_pred_mlr = mlr.predict(x_test)

print("R2 Score:", r2_score(y_test, y_pred_mlr))
# Out:
# R2 Score: 0.33878922443157355

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# Using one feature for polynomial regression
x_train_1 = x_train.iloc[:, [0]]
x_test_1 = x_test.iloc[:, [0]]

poly = PolynomialFeatures(degree=2)

x_poly_train = poly.fit_transform(x_train_1)
x_poly_test = poly.transform(x_test_1)

poly_model = LinearRegression()

poly_model.fit(x_poly_train, y_train)

y_poly_pred = poly_model.predict(x_poly_test)

print("Polynomial Regression R2 Score:", r2_score(y_test, y_poly_pred))
# Out:
# Polynomial Regression R2 Score: -5.1416583110919234e-05

# %%
plt.figure(figsize=(10,6))

plt.scatter(y_test, y_poly_pred, alpha=0.5)

plt.title('Polynomial Regression Prediction')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')

plt.show()
